# %% [markdown]
# # 1.
# Scan over the whole original csv and encode each tag into a tag index, forming functions `tag2index` `index2tag`

# %%
import pandas as pd
import tqdm

# %%
df = pd.read_csv("ori_tags.csv")
df.head()
# Out:
#    id                                            img_src  \
# 0   1  //safebooru.org//samples/1/sample_e7b3dc281d43...
# 1   2  //safebooru.org//samples/1/sample_27ff11b17a2c...
# 2   3  //safebooru.org//samples/1/sample_ebd16eb1d154...
# 3   4  //safebooru.org//samples/1/sample_6fbb9a4b9099...
# 4   6  //safebooru.org//samples/1/sample_113cb63dc541...
#
#                                                 tags  \
# 0  1girl,bag,black hair,blush,bob cut,bowieknife,...
# 1  barding,black,cape,celty sturluson,dress,dulla...
# 2  blue eyes,blush,brown hair,original,scan,takoy...
# 3  game cg,hagall valkyr,mecha musume,shirogane n...
# 4  blush,idolmaster,kisaragi chihaya,komi zumiko,...
#
#                                                types
# 0  tag-type-general,tag-type-general,tag-type-gen...
# 1  tag-type-general,tag-type-general,tag-type-gen...
# 2  tag-type-general,tag-type-general,tag-type-gen...
# 3  tag-type-general,tag-type-character,tag-type-g...
# 4  tag-type-general,tag-type-copyright,tag-type-c...

# %% [markdown]
# # 2.
# Count all tags using `Counter`, as our task only focus on background removal, just find the most popular 512 `general`(which I call it `attribute`) tags

# %%
from collections import Counter
tags_count = Counter()
err = []
for _ in tqdm.tqdm(range(len(df))):
    img = df.iloc[_]
    tags = img['tags'].split(",")
    tags_type = img['types'].split(",")
    # Here are some error crawled data whose tags and tags_type can not match
    if len(tags)==len(tags_type):
        for i,t in enumerate(tags):
            if tags_type[i]=="tag-type-general":
                tags_count[t]+=1
    else:
        err.append(_)

# %%
tag2index = {}
index2tag = {}
for i,k in enumerate(tags_count):
    tag = k[0]
    tag2index[tag]=i
    index2tag[i] = tag

# %% [markdown]
# # 3.
# Filter out those images which don't include these 512 tag
# # 4.
# Reindex these tags to 0~511

# %%
attribute_tags = tags_count.most_common(512)
most_common_tags = []
commontag2index = {}
index2commontag = {}
for i,k in enumerate(attribute_tags):
    commontag2index[k[0]]=i
    index2commontag[i]=k[0]
    most_common_tags.append(k[0])
    print(k)
most_common_tags = set(most_common_tags)
# Out:
# ('solo', 1146592)
# ('1girl', 1066555)
# ('long hair', 1065307)
# ('highres', 847419)
# ('smile', 712395)
# ('short hair', 688384)
# ('blush', 567867)
# ('looking at viewer', 529824)
# ('open mouth', 498766)
# ('blue eyes', 471414)
# ('breasts', 467375)
# ('blonde hair', 464963)
# ('multiple girls', 447898)
# ('brown hair', 437928)
# ('skirt', 435995)
# ('hat', 419104)
# ('black hair', 369230)
# ('red eyes', 364148)
# ('dress', 337524)
# ('ribbon', 321530)
# ('gloves', 309668)
# ('hair ornament', 301210)
# ('simple background', 290922)
# ('thigh-highs', 286132)
# ('school uniform', 282261)
# ('bow', 278287)
# ('twintails', 275824)
# ('brown eyes', 266425)
# ('translation request', 252073)
# ('green eyes', 235082)
# ('white background', 231191)
# ('blue hair', 225044)
# ('monochrome', 223617)
# ('2girls', 220068)
# ('bangs', 214385)
# ('sitting', 211839)
# ('weapon', 210262)
# ('comic', 203962)
# ('cleavage', 202957)
# ('long sleeves', 200933)
# ('shirt', 197192)
# ('animal ears', 195516)
# ('jewelry', 188254)
# ('very long hair', 181549)
# ('closed eyes', 180714)
# ('hair ribbon', 179012)
# ('1boy', 178980)
# ('bare shoulders', 175947)
# ('violet eyes', 172213)
# ('ponytail', 172020)
# ('eyebrows visible through hair', 165736)
# ('large breasts', 165396)
# ('yellow eyes', 163620)
# ('flower', 162732)
# ('pink hair', 161417)
# ('hair bow', 160365)
# ('purple hair', 159593)
# ('absurdres', 159475)
# ('silver hair', 151679)
# ('black legwear', 148559)
# ('commentary request', 147136)
# ('navel', 144329)
# ('tail', 142955)
# ('wings', 139501)
# ('braid', 137834)
# ('holding', 137807)
# ('japanese clothes', 136042)
# ('boots', 133108)
# ('hairband', 132074)
# ('green hair', 129975)
# ('pantyhose', 129610)
# ('standing', 127260)
# ('redhead', 126565)
# ('serafuku', 126548)
# ('ahoge', 124747)
# ('detached sleeves', 122956)
# ('tagme', 122585)
# ('swimsuit', 121423)
# ('hair between eyes', 119609)
# ('glasses', 119587)
# ('underwear', 116466)
# ('necktie', 115686)
# ('thighhighs', 114974)
# ('translated', 114437)
# (':d', 114384)
# ('pleated skirt', 109365)
# ('sword', 108197)
# ('short sleeves', 106725)
# ('white hair', 103963)
# ('heart', 102607)
# ('full body', 101731)
# ('food', 101032)
# ('jacket', 99603)
# ('sky', 98377)
# ('collarbone', 98301)
# ('panties', 95887)
# ('closed mouth', 93479)
# ('shoes', 93168)
# ('multiple boys', 90653)
# ('frills', 83410)
# ('earrings', 82880)
# ('official art', 82825)
# ('midriff', 82148)
# ('bikini', 80790)
# ('chibi', 80423)
# ('alternate costume', 79579)
# ('shorts', 79532)
# ('upper body', 78943)
# ('white legwear', 78937)
# ('elbow gloves', 77607)
# ('medium breasts', 76685)
# ('fang', 76210)
# ('bad id', 73486)
# ('barefoot', 73209)
# ('hairclip', 72529)
# ('scarf', 72296)
# ('cat ears', 68803)
# ('cape', 68456)
# ('one eye closed', 68431)
# ('uniform', 67489)
# ('puffy sleeves', 67414)
# ('belt', 66914)
# ('side ponytail', 66769)
# ('striped', 66766)
# ('pointy ears', 66255)
# ('white shirt', 65494)
# ('cowboy shot', 65304)
# ('kimono', 64692)
# ('horns', 63812)
# ('tears', 63265)
# ('sleeveless', 63138)
# ('choker', 62838)
# ('multicolored hair', 62662)
# ('fingerless gloves', 62621)
# ('pink eyes', 61333)
# ('parted lips', 60209)
# ('clouds', 60052)
# ('zettai ryouiki', 59923)
# ('hair flower', 59464)
# ('star', 59122)
# ('lying', 58190)
# ('wide sleeves', 57479)
# ('3girls', 57221)
# ('character name', 56595)
# ('ass', 55698)
# ('white gloves', 55216)
# ('sidelocks', 55098)
# ('male focus', 54992)
# ('male', 54963)
# ('outdoors', 54890)
# ('armor', 54403)
# ('black eyes', 54250)
# ('bag', 54049)
# ('lowres', 53352)
# ('orange hair', 52323)
# ('looking back', 51238)
# ('wink', 50878)
# ('female', 50650)
# ('sketch', 50608)
# ('twin braids', 50436)
# ('necklace', 50149)
# ('water', 49314)
# ('sweatdrop', 49253)
# ('purple eyes', 49240)
# ('gun', 49061)
# ('black gloves', 49036)
# ('grey hair', 48810)
# ('artist name', 48266)
# ('socks', 48067)
# ('2boys', 48033)
# ('miniskirt', 47803)
# ('aqua eyes', 47674)
# ('apron', 47212)
# ('book', 47118)
# ('grin', 47039)
# ('military', 46141)
# ('greyscale', 46138)
# ('vest', 45958)
# ('red hair', 45323)
# ('signature', 44158)
# ('tree', 43758)
# ('tongue', 42928)
# ('hug', 42544)
# ('bowtie', 42261)
# ('commentary', 42253)
# ('4koma', 41954)
# ('cosplay', 41867)
# ('bracelet', 41813)
# ('maid', 41277)
# ('hair over one eye', 41159)
# ('petals', 40922)
# ('thighs', 40680)
# ('rabbit ears', 39903)
# ('military uniform', 39853)
# ('pants', 39770)
# ('open clothes', 39753)
# ('hood', 39335)
# ('high heels', 39199)
# ('white dress', 39111)
# ('yuri', 39083)
# ('twitter username', 39012)
# ('teeth', 38853)
# ('aqua hair', 38654)
# ('blunt bangs', 38482)
# ('headphones', 38297)
# ('dated', 38213)
# ('black skirt', 37685)
# ('small breasts', 37663)
# (':o', 37518)
# ('cat tail', 37500)
# ('ascot', 36724)
# ('witch hat', 36360)
# ('dark skin', 35768)
# ('wrist cuffs', 35561)
# ('hand on hip', 35561)
# ('kneehighs', 35073)
# ('umbrella', 34974)
# ('magical girl', 34926)
# ('nail polish', 34852)
# ('lips', 34489)
# ('sweater', 34049)
# ('fruit', 34038)
# ('sailor collar', 33902)
# ('parody', 33543)
# ('plaid', 32932)
# ('looking at another', 32800)
# ('neckerchief', 32799)
# ('headband', 32645)
# ('maid headdress', 32410)
# ('traditional media', 32133)
# ('from behind', 32112)
# ('holding weapon', 31981)
# ('sash', 31967)
# ('black dress', 31957)
# ('blood', 31581)
# ('armpits', 31533)
# ('puffy short sleeves', 31357)
# ('eyes closed', 31034)
# ('cup', 30954)
# ('collared shirt', 30494)
# ('personification', 30318)
# ('moon', 30304)
# ('siblings', 30282)
# ('legs', 30071)
# ('hair tubes', 30065)
# ('capelet', 30023)
# ('head tilt', 29813)
# ('arm up', 29647)
# ('rose', 29561)
# ('headgear', 29391)
# ('orange eyes', 29375)
# ('single braid', 29353)
# ('alternate hairstyle', 29296)
# ('sparkle', 29237)
# ('eyebrows', 29197)
# ('coat', 28802)
# ('^ ^', 28644)
# ('grey background', 28427)
# ('shiny', 28378)
# ('mask', 28330)
# ('night', 28166)
# ('day', 28072)
# ('kneeling', 27917)
# ('grey eyes', 27845)
# ('glowing', 27803)
# ('v', 27731)
# ('no humans', 27588)
# ('double bun', 27352)
# ('bra', 27277)
# ('4girls', 27240)
# ('eating', 27178)
# ('bird', 27177)
# ('collar', 27115)
# ('hoodie', 27051)
# ('two side up', 26890)
# ('drill hair', 26842)
# ('english', 26836)
# ('bodysuit', 26815)
# ('blue sky', 26752)
# (':3', 26606)
# ('feet', 26571)
# ('eyepatch', 26558)
# ('cat', 25804)
# ('gradient', 25713)
# ('arms up', 25633)
# ('fox ears', 25342)
# ('blush stickers', 25270)
# ('leaf', 25175)
# ('mole', 25164)
# ('red ribbon', 24785)
# ('tongue out', 24698)
# ('dutch angle', 24688)
# ('katana', 24597)
# ('hat ribbon', 24521)
# ('flat chest', 24491)
# ('bat wings', 24265)
# ('blue skirt', 24116)
# ('scan', 24015)
# ('child', 23981)
# ('gradient background', 23944)
# ('striped legwear', 23928)
# ('from side', 23832)
# ('fox tail', 23783)
# ('profile', 23749)
# ('indoors', 23711)
# ('two-tone hair', 23590)
# ('heterochromia', 23524)
# ('sleeping', 23452)
# ('copyright name', 23295)
# ('thigh boots', 23264)
# ('formal', 23224)
# ('hand up', 23119)
# ('bell', 23114)
# ('white panties', 23108)
# ('off shoulder', 23106)
# ('bare legs', 22930)
# ('fingernails', 22881)
# ('one-piece swimsuit', 22844)
# ('sleeves past wrists', 22801)
# ('crossover', 22757)
# ('dress shirt', 22428)
# ('red bow', 22328)
# ('blurry', 22316)
# ('crossed arms', 22285)
# ('6+girls', 22103)
# ('obi', 22095)
# ('leotard', 22005)
# ('happy', 22003)
# ('on back', 21912)
# ('stuffed toy', 21802)
# ('couple', 21794)
# ('beret', 21744)
# ('blue dress', 21710)
# ('skirt set', 21653)
# ('sandals', 21649)
# ('window', 21627)
# ('fur trim', 21534)
# ('hair bobbles', 21500)
# ('facial hair', 21208)
# ('plaid skirt', 21111)
# ('face', 21053)
# ('short shorts', 20940)
# ('polearm', 20804)
# ('school swimsuit', 20699)
# ('outstretched arms', 20554)
# ('pillow', 20463)
# ('pantyshot', 20247)
# ('makeup', 20238)
# ('chinese clothes', 20223)
# ('torn clothes', 20193)
# ('ocean', 20155)
# ('wariza', 20151)
# ('blazer', 20113)
# ('short twintails', 20109)
# ('stuffed animal', 19899)
# ('leaning forward', 19826)
# ('holding hands', 19820)
# ('helmet', 19688)
# ('fire', 19674)
# ('eyelashes', 19618)
# ('casual', 19562)
# ('suit', 19525)
# ('mob cap', 19500)
# ('fangs', 19451)
# ('transparent background', 19332)
# ('looking to the side', 19306)
# ('garter straps', 19267)
# ('gradient hair', 19205)
# ('> <', 19088)
# ('scar', 19086)
# ('instrument', 18941)
# ('suspenders', 18921)
# ('tokin hat', 18869)
# ('tattoo', 18864)
# ('chair', 18857)
# ('staff', 18854)
# ('knife', 18751)
# ('sideboob', 18602)
# ('turtleneck', 18555)
# ('cherry blossoms', 18499)
# ('crown', 18458)
# ('black ribbon', 18399)
# ('wolf ears', 18347)
# ('sleeveless dress', 18298)
# ('hair bun', 18222)
# ('wavy hair', 18045)
# ('facial mark', 18042)
# ('flying sweatdrops', 18014)
# ('bust', 18013)
# ('third eye', 18008)
# ('pointing', 18006)
# ('mecha', 17949)
# ('speech bubble', 17917)
# ('sleeveless shirt', 17914)
# ('pokemon (creature)', 17908)
# ('wallpaper', 17870)
# ('frown', 17865)
# ('mouth hold', 17758)
# ('depth of field', 17754)
# ('miko', 17632)
# ('low twintails', 17511)
# ('cover', 17386)
# ('remodel (kantai collection)', 17365)
# ('bare arms', 17178)
# ('floating hair', 17160)
# ('sisters', 17159)
# ('looking away', 17139)
# ('wet', 17067)
# ('genderswap', 17045)
# ('multiple tails', 17021)
# ('gauntlets', 17013)
# ('table', 17003)
# ('shadow', 16927)
# ('see-through', 16909)
# ('side-tie bikini', 16868)
# ('red skirt', 16839)
# ('microphone', 16770)
# ('backpack', 16751)
# ('detached collar', 16671)
# ('wavy mouth', 16646)
# ('lipstick', 16624)
# ('hand holding', 16582)
# ('expressionless', 16553)
# ('animal', 16452)
# ('goggles', 16448)
# ('shinkaisei-kan', 16410)
# ('beach', 16409)
# ('open jacket', 16340)
# ('watermark', 16339)
# ('fan', 16267)
# ('nature', 16250)
# ('butterfly', 16249)
# ('bunny ears', 16231)
# ('crop top', 16231)
# ('phone', 16225)
# ('feathers', 16156)
# ('grass', 16151)
# ('red dress', 16144)
# ('shiny hair', 16140)
# ('floral print', 16121)
# ('parted bangs', 16073)
# ('black panties', 16052)
# ('polka dot', 16035)
# ('bike shorts', 15955)
# ('blue background', 15953)
# ('cleavage cutout', 15952)
# ('buttons', 15925)
# ('peaked cap', 15780)
# ('light smile', 15693)
# ('hat bow', 15638)
# ('chain', 15637)
# ('cloud', 15606)
# ('from above', 15583)
# ('short dress', 15582)
# ('neck ribbon', 15505)
# (';d', 15471)
# ('symbol-shaped pupils', 15426)
# ('wind', 15407)
# ('head wings', 15331)
# ('arm support', 15278)
# ('cardigan', 15264)
# ('broom', 15252)
# ('strapless', 15199)
# ('bed', 15174)
# ('black footwear', 15155)
# ('musical note', 15098)
# ('outstretched arm', 15023)
# ('snow', 14953)
# ('crescent', 14930)
# ('knee boots', 14924)
# ('chains', 14924)
# ('sheath', 14883)
# ('black bow', 14853)
# ('blouse', 14843)
# ('tiara', 14759)
# ('glowing eyes', 14752)
# ('sunglasses', 14711)
# ('crying', 14706)
# ('stomach', 14656)
# ('scenery', 14628)
# ('text', 14567)
# ('checkered', 14484)
# ('thigh strap', 14417)
# ('spoilers', 14369)
# ('no hat', 14333)
# ('game cg', 14248)
# ('5girls', 14233)
# ('scrunchie', 14232)
# ('shaded face', 14173)
# ('pale skin', 14154)
# ('sunlight', 14105)
# ('machinery', 14075)
# ('arms behind back', 14041)
# ('embarrassed', 14029)
# ('kiss', 13950)
# ('adapted costume', 13911)
# ('bunnysuit', 13901)
# ('dual persona', 13773)
# ('star (sky)', 13747)
# ('loafers', 13603)
# ('bottle', 13571)
# ('mary janes', 13526)
# ('cellphone', 13518)
# ('younger', 13508)
# ('antenna hair', 13482)
# ('letterboxed', 13474)
# ('frilled skirt', 13473)
# ('on side', 13433)
# ('monster girl', 13426)
# ('ring', 13412)
# ('standing on one leg', 13394)
# ('covered navel', 13390)

# %%
cleaned_img_id = []
cleaned_img_tags_index = []
#for _ in tqdm.tqdm(range(10)):
for _ in tqdm.tqdm(range(len(df))):
    img = df.iloc[_]
    tags = img['tags'].split(",")
    tags_index = []
    for i,t in enumerate(tags):
        if t in most_common_tags:                
            tags_index.append(commontag2index[t])
    cleaned_img_id.append(img["id"])
    tags_index.sort()
    cleaned_img_tags_index.append(tags_index)

# %%
cleaned_df = pd.DataFrame({"id":cleaned_img_id,"attr_index":cleaned_img_tags_index})  
cleaned_df.head()
# Out:
#                                           attr_index  id
# 0  [0, 1, 5, 6, 14, 16, 20, 70, 81, 92, 115, 119,...   1
# 1                                    [0, 3, 18, 117]   2
# 2                        [6, 9, 13, 23, 26, 83, 297]   3
# 3                                      [63, 86, 485]   4
# 4                                           [6, 297]   6

# %% [markdown]
# # 5.
# Construct a dict which maps `image_id` to `attr_index`. And we should be aware of those pictures which are not successful downloaded, they cound cause pytorch dataloader exception, so we need to clean them by using `os.path.exists`.Finally, we cache it to `img_id2attr.pkl`, so that the training set is produced

# %%
import numpy as np
imgid2attr={}
for i,id in tqdm.tqdm(enumerate(cleaned_img_id)):
    attr = np.array(cleaned_img_tags_index[i])
    imgid2attr[id]=attr

# %%
import os
import tqdm
path = "../home4/i2v_data/images/"
ids = imgid2attr.keys()
missing_img = []
for i in tqdm.tqdm(ids):
    found = False
    for _ in [".jpg",".png",".jpeg",".gif"]:
        img_path = os.path.join(path, str(i) + _)
        if os.path.exists(img_path):
            #print(img_path)
            found = True
            break
    if not found:
        missing_img.append(i)
# Out:
# 100%|██████████| 2530261/2530261 [00:19<00:00, 130217.91it/s]

# %%
print(len(missing_img))
for i in missing_img:
    if i in imgid2attr.keys():
        print(i)
        del imgid2attr[i]

# %%
import pickle
with open("imgid2attr.pkl","wb") as f:
    pkl = pickle.dumps(imgid2attr)
    f.write(pkl)
